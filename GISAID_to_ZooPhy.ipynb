# %% [markdown]
# <a href="https://colab.research.google.com/github/ZooPhy/zoophy-utils-/blob/master/GISAID_to_ZooPhy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Format GISAID's FASTA files for the ZooPhy pipeline
# Notebook that converts [GISAID](https://www.gisaid.org/) FASTA files that contain viral sequences to the FASTA format accepted by the [ZooPhy](https://zodo.asu.edu/zoophy/) pipeline for Virus Phylogeography. We use examples from the now active COVID19 (also known as SARS-CoV-2) outbreak. This can be used for FLU sequences as well.
#
# ## Requirements
# Here is what you require as inputs to this notebook:
#
# 1) ```FASTA Files``` (GISAID sequence files in FASTA format compressed into a .zip file)
#
# 2) ```Acknowledgement Table``` for the submissions (a .xls file available for download below the table of search results)

# %% [markdown]
# Run the following cell (click the play button) to import necessary libraries required for running this notebook and simple utility functions. It should also produce a button for uploading the ```.zip``` file and the table ```.xls``` file. Select both the files in this step.

# %%
import os
import zipfile
import pandas as pd
from os import listdir, remove, removedirs, makedirs
from os.path import join, exists, isdir, isfile
from google.colab import files
import shutil

def show_files():
    print("Current Directory Contents:", [x for x in os.listdir() if x[0] not in ['.', '_']])

def clear_file_system():
    files_to_delete = [x for x in os.listdir() if x not in ['.', '_']]
    while(files_to_delete):
        files_to_delete = [x for x in os.listdir() if x not in ['.', '_']]
        for x in files_to_delete:
            if isfile(x):
                remove(x)
            else:
                shutil.rmtree(x, ignore_errors=True)

# remove unnecessary files and upload GISAID files
clear_file_system()
print("Upload the .zip file containing fasta files and .xls file containing the Acknowledgement table")
uploaded = files.upload()
if uploaded and len(uploaded)>=2:
    show_files()
    zipf = [x for x in uploaded if x.endswith('zip')][0]
    print("\n\nzip file selected: '"+zipf+"'" if zipf else "Please upload file with .zip extension")
    xlsf = [x for x in uploaded if x.endswith('xls')][0]
    print("xls file selected: '"+xlsf+"'" if xlsf else "Please upload file with .xls extension")
else:
    print("\n\nPlease select both .zip and .xls files.")
# Out:
# Upload the .zip file containing fasta files and .xls file containing the Acknowledgement table
#      <input type="file" id="files-09fdd2d2-a6f2-4f5c-b74b-932a35bd6e25" name="files[]" multiple disabled />
#      <output id="result-09fdd2d2-a6f2-4f5c-b74b-932a35bd6e25">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gisaid-04Mar2020.zip to gisaid-04Mar2020.zip
# Saving gisaid_cov2020_acknowledgement_table.xls to gisaid_cov2020_acknowledgement_table.xls
# Current Directory Contents: ['gisaid_cov2020_acknowledgement_table.xls', 'gisaid-04Mar2020.zip']
#
#
# zip file selected: 'gisaid-04Mar2020.zip'
# xls file selected: 'gisaid_cov2020_acknowledgement_table.xls'

# %% [markdown]
# Running the following cell extracts the fasta files into a new directory and extracts metadata

# %%
ZIP_DIR = 'fasta_files'
# empty fasta directory if exists
if exists(ZIP_DIR):
    shutil.rmtree(ZIP_DIR, ignore_errors=True)
# create directory
makedirs(ZIP_DIR)
# unzip the zipfile
if zipf and xlsf:
    try:
        with zipfile.ZipFile(zipf, 'r') as zip_ref:
            filelist = [x for x in zip_ref.namelist() if x.strip() and x.strip()[0] not in ["_", "."] and x.strip().lower().endswith('fasta')]
            print("Extracting from", zipf, filelist)
            for fl in filelist:
                print("Extracting", fl)
                zip_ref.extract(fl, path=ZIP_DIR)
                if "/" in fl:
                    sdir, gf = fl.split("/")
                    print("Moving", join(join(ZIP_DIR, sdir), gf))
                    os.system("mv "+join(join(ZIP_DIR, sdir), gf)+" "+ZIP_DIR)
                    remove_list.append(join(ZIP_DIR, sdir))
    except Exception as e:
        print("Exception", e, " while extracting file", zipf)
    try:
        xdf = pd.read_excel(xlsf, header=2, index_col=0)
        print("Loaded Acknowledgement Table with ", list(xdf.columns))
    except Exception as e:
        print("Exception", e, " while processing ", xlsf)
else:
    print("It seems as though the zip and xls files don't exist in Runtime. Please run previous cells again.")
# Out:
# Extracting from gisaid-04Mar2020.zip ['EPI_ISL_402119.fasta', 'EPI_ISL_402120.fasta', 'EPI_ISL_402121.fasta', 'EPI_ISL_402123.fasta', 'EPI_ISL_402124.fasta', 'EPI_ISL_402125.fasta', 'EPI_ISL_402126.fasta', 'EPI_ISL_402127.fasta', 'EPI_ISL_402128.fasta', 'EPI_ISL_402129.fasta', 'EPI_ISL_402130.fasta', 'EPI_ISL_402132.fasta', 'EPI_ISL_403928.fasta', 'EPI_ISL_403929.fasta', 'EPI_ISL_403930.fasta', 'EPI_ISL_403931.fasta', 'EPI_ISL_403932.fasta', 'EPI_ISL_403933.fasta', 'EPI_ISL_403934.fasta', 'EPI_ISL_403935.fasta', 'EPI_ISL_403936.fasta', 'EPI_ISL_403937.fasta', 'EPI_ISL_403962.fasta', 'EPI_ISL_403963.fasta', 'EPI_ISL_404227.fasta', 'EPI_ISL_404228.fasta', 'EPI_ISL_404253.fasta', 'EPI_ISL_404895.fasta', 'EPI_ISL_405839.fasta', 'EPI_ISL_406030.fasta', 'EPI_ISL_406031.fasta', 'EPI_ISL_406034.fasta', 'EPI_ISL_406036.fasta', 'EPI_ISL_406223.fasta', 'EPI_ISL_406531.fasta', 'EPI_ISL_406533.fasta', 'EPI_ISL_406534.fasta', 'EPI_ISL_406535.fasta', 'EPI_ISL_406536.fasta', 'EPI_ISL_406538.fasta', 'EPI_ISL_406592.fasta', 'EPI_ISL_406593.fasta', 'EPI_ISL_406594.fasta', 'EPI_ISL_406595.fasta', 'EPI_ISL_406596.fasta', 'EPI_ISL_406597.fasta', 'EPI_ISL_406716.fasta', 'EPI_ISL_406717.fasta', 'EPI_ISL_406798.fasta', 'EPI_ISL_406799.fasta', 'EPI_ISL_406800.fasta', 'EPI_ISL_406801.fasta', 'EPI_ISL_406844.fasta', 'EPI_ISL_406862.fasta', 'EPI_ISL_406959.fasta', 'EPI_ISL_406960.fasta', 'EPI_ISL_406970.fasta', 'EPI_ISL_406973.fasta', 'EPI_ISL_407071.fasta', 'EPI_ISL_407073.fasta', 'EPI_ISL_407079.fasta', 'EPI_ISL_407084.fasta', 'EPI_ISL_407193.fasta', 'EPI_ISL_407214.fasta', 'EPI_ISL_407215.fasta', 'EPI_ISL_407313.fasta', 'EPI_ISL_407893.fasta', 'EPI_ISL_407894.fasta', 'EPI_ISL_407896.fasta', 'EPI_ISL_407976.fasta', 'EPI_ISL_407987.fasta', 'EPI_ISL_407988.fasta', 'EPI_ISL_408008.fasta', 'EPI_ISL_408009.fasta', 'EPI_ISL_408010.fasta', 'EPI_ISL_408068.fasta', 'EPI_ISL_408430.fasta', 'EPI_ISL_408431.fasta', 'EPI_ISL_408478.fasta', 'EPI_ISL_408479.fasta', 'EPI_ISL_408480.fasta', 'EPI_ISL_408481.fasta', 'EPI_ISL_408482.fasta', 'EPI_ISL_408483.fasta', 'EPI_ISL_408484.fasta', 'EPI_ISL_408485.fasta', 'EPI_ISL_408486.fasta', 'EPI_ISL_408487.fasta', 'EPI_ISL_408488.fasta', 'EPI_ISL_408489.fasta', 'EPI_ISL_408511.fasta', 'EPI_ISL_408512.fasta', 'EPI_ISL_408513.fasta', 'EPI_ISL_408514.fasta', 'EPI_ISL_408515.fasta', 'EPI_ISL_408665.fasta', 'EPI_ISL_408666.fasta', 'EPI_ISL_408667.fasta', 'EPI_ISL_408668.fasta', 'EPI_ISL_408669.fasta', 'EPI_ISL_408670.fasta', 'EPI_ISL_408975.fasta', 'EPI_ISL_408976.fasta', 'EPI_ISL_408977.fasta', 'EPI_ISL_408978.fasta', 'EPI_ISL_408994.fasta', 'EPI_ISL_408995.fasta', 'EPI_ISL_408996.fasta', 'EPI_ISL_408997.fasta', 'EPI_ISL_408998.fasta', 'EPI_ISL_408999.fasta', 'EPI_ISL_409000.fasta', 'EPI_ISL_409001.fasta', 'EPI_ISL_409002.fasta', 'EPI_ISL_409020.fasta', 'EPI_ISL_409022.fasta', 'EPI_ISL_409023.fasta', 'EPI_ISL_409024.fasta', 'EPI_ISL_409025.fasta', 'EPI_ISL_409026.fasta', 'EPI_ISL_409027.fasta', 'EPI_ISL_409067.fasta', 'EPI_ISL_410044.fasta', 'EPI_ISL_410045.fasta', 'EPI_ISL_410218.fasta', 'EPI_ISL_410301.fasta', 'EPI_ISL_410302.fasta', 'EPI_ISL_410314.fasta', 'EPI_ISL_410344.fasta', 'EPI_ISL_410345.fasta', 'EPI_ISL_410486.fasta', 'EPI_ISL_410487.fasta', 'EPI_ISL_410488.fasta', 'EPI_ISL_410489.fasta', 'EPI_ISL_410531.fasta', 'EPI_ISL_410532.fasta', 'EPI_ISL_410535.fasta', 'EPI_ISL_410536.fasta', 'EPI_ISL_410537.fasta', 'EPI_ISL_410545.fasta', 'EPI_ISL_410546.fasta', 'EPI_ISL_410713.fasta', 'EPI_ISL_410714.fasta', 'EPI_ISL_410715.fasta', 'EPI_ISL_410716.fasta', 'EPI_ISL_410717.fasta', 'EPI_ISL_410718.fasta', 'EPI_ISL_410719.fasta', 'EPI_ISL_410720.fasta', 'EPI_ISL_410984.fasta', 'EPI_ISL_411060.fasta', 'EPI_ISL_411066.fasta', 'EPI_ISL_411218.fasta', 'EPI_ISL_411219.fasta', 'EPI_ISL_411220.fasta', 'EPI_ISL_411902.fasta', 'EPI_ISL_411915.fasta', 'EPI_ISL_411926.fasta', 'EPI_ISL_411927.fasta', 'EPI_ISL_411929.fasta', 'EPI_ISL_411949.fasta', 'EPI_ISL_411950.fasta', 'EPI_ISL_411951.fasta', 'EPI_ISL_411952.fasta', 'EPI_ISL_411953.fasta', 'E ...
# Extracting EPI_ISL_402119.fasta
# Extracting EPI_ISL_402120.fasta
# Extracting EPI_ISL_402121.fasta
# Extracting EPI_ISL_402123.fasta
# Extracting EPI_ISL_402124.fasta
# Extracting EPI_ISL_402125.fasta
# Extracting EPI_ISL_402126.fasta
# Extracting EPI_ISL_402127.fasta
# Extracting EPI_ISL_402128.fasta
# Extracting EPI_ISL_402129.fasta
# Extracting EPI_ISL_402130.fasta
# Extracting EPI_ISL_402132.fasta
# Extracting EPI_ISL_403928.fasta
# Extracting EPI_ISL_403929.fasta
# Extracting EPI_ISL_403930.fasta
# Extracting EPI_ISL_403931.fasta
# Extracting EPI_ISL_403932.fasta
# Extracting EPI_ISL_403933.fasta
# Extracting EPI_ISL_403934.fasta
# Extracting EPI_ISL_403935.fasta
# Extracting EPI_ISL_403936.fasta
# Extracting EPI_ISL_403937.fasta
# Extracting EPI_ISL_403962.fasta
# Extracting EPI_ISL_403963.fasta
# Extracting EPI_ISL_404227.fasta
# Extracting EPI_ISL_404228.fasta
# Extracting EPI_ISL_404253.fasta
# Extracting EPI_ISL_404895.fasta
# Extracting EPI_ISL_405839.fasta
# Extracting EPI_ISL_406030.fasta
# Extracting EPI_ISL_406031.fasta
# Extracting EPI_ISL_406034.fasta
# Extracting EPI_ISL_406036.fasta
# Extracting EPI_ISL_406223.fasta
# Extracting EPI_ISL_406531.fasta
# Extracting EPI_ISL_406533.fasta
# Extracting EPI_ISL_406534.fasta
# Extracting EPI_ISL_406535.fasta
# Extracting EPI_ISL_406536.fasta
# Extracting EPI_ISL_406538.fasta
# Extracting EPI_ISL_406592.fasta
# Extracting EPI_ISL_406593.fasta
# Extracting EPI_ISL_406594.fasta
# Extracting EPI_ISL_406595.fasta
# Extracting EPI_ISL_406596.fasta
# Extracting EPI_ISL_406597.fasta
# Extracting EPI_ISL_406716.fasta
# Extracting EPI_ISL_406717.fasta
# Extracting EPI_ISL_406798.fasta
# Extracting EPI_ISL_406799.fasta
# Extracting EPI_ISL_406800.fasta
# Extracting EPI_ISL_406801.fasta
# Extracting EPI_ISL_406844.fasta
# Extracting EPI_ISL_406862.fasta
# Extracting EPI_ISL_406959.fasta
# Extracting EPI_ISL_406960.fasta
# Extracting EPI_ISL_406970.fasta
# Extracting EPI_ISL_406973.fasta
# Extracting EPI_ISL_407071.fasta
# Extracting EPI_ISL_407073.fasta
# Extracting EPI_ISL_407079.fasta
# Extracting EPI_ISL_407084.fasta
# Extracting EPI_ISL_407193.fasta
# Extracting EPI_ISL_407214.fasta
# Extracting EPI_ISL_407215.fasta
# Extracting EPI_ISL_407313.fasta
# Extracting EPI_ISL_407893.fasta
# Extracting EPI_ISL_407894.fasta
# Extracting EPI_ISL_407896.fasta
# Extracting EPI_ISL_407976.fasta
# Extracting EPI_ISL_407987.fasta
# Extracting EPI_ISL_407988.fasta
# Extracting EPI_ISL_408008.fasta
# Extracting EPI_ISL_408009.fasta
# Extracting EPI_ISL_408010.fasta
# Extracting EPI_ISL_408068.fasta
# Extracting EPI_ISL_408430.fasta
# Extracting EPI_ISL_408431.fasta
# Extracting EPI_ISL_408478.fasta
# Extracting EPI_ISL_408479.fasta
# Extracting EPI_ISL_408480.fasta
# Extracting EPI_ISL_408481.fasta
# Extracting EPI_ISL_408482.fasta
# Extracting EPI_ISL_408483.fasta
# Extracting EPI_ISL_408484.fasta
# Extracting EPI_ISL_408485.fasta
# Extracting EPI_ISL_408486.fasta
# Extracting EPI_ISL_408487.fasta
# Extracting EPI_ISL_408488.fasta
# Extracting EPI_ISL_408489.fasta
# Extracting EPI_ISL_408511.fasta
# Extracting EPI_ISL_408512.fasta
# Extracting EPI_ISL_408513.fasta
# Extracting EPI_ISL_408514.fasta
# Extracting EPI_ISL_408515.fasta
# Extracting EPI_ISL_408665.fasta
# Extracting EPI_ISL_408666.fasta
# Extracting EPI_ISL_408667.fasta
# Extracting EPI_ISL_408668.fasta
# Extracting EPI_ISL_408669.fasta
# Extracting EPI_ISL_408670.fasta
# Extracting EPI_ISL_408975.fasta
# Extracting EPI_ISL_408976.fasta
# Extracting EPI_ISL_408977.fasta
# Extracting EPI_ISL_408978.fasta
# Extracting EPI_ISL_408994.fasta
# Extracting EPI_ISL_408995.fasta
# Extracting EPI_ISL_408996.fasta
# Extracting EPI_ISL_408997.fasta
# Extracting EPI_ISL_408998.fasta
# Extracting EPI_ISL_408999.fasta
# Extracting EPI_ISL_409000.fasta
# Extracting EPI_ISL_409001.fasta
# Extracting EPI_ISL_409002.fasta
# Extracting EPI_ISL_409020.fasta
# Extracting EPI_ISL_409022.fasta
# Extracting EPI_ISL_409023.fasta
# Extracting EPI_ISL_409024.fasta
# Extracting EPI_ISL_409025.fasta
# Extracting EPI_ISL_409026.fasta
# Extracting EPI_ISL_409027.fasta
# Extracting EPI_ISL_409067.fasta
# Extracting EPI_ISL_410044.fasta
# Extracting EPI_ISL_410045.fasta
# Extracting EPI_ISL_410218.fasta
# Extracting EPI_ISL_410301.fasta
# Extracting EPI_ISL_410302.fasta
# Extracting EPI_ISL_410314.fasta
# Extracting EPI_ISL_410344.fasta
# Extracting EPI_ISL_410345.fasta
# Extracting EPI_ISL_410486.fasta
# Extracting EPI_ISL_410487.fasta
# Extracting EPI_ISL_410488.fasta
# Extracting EPI_ISL_410489.fasta
# Extracting EPI_ISL_410531.fasta
# Extracting EPI_ISL_410532.fasta
# Extracting EPI_ISL_410535.fasta
# Extracting EPI_ISL_410536.fasta
# Extracting EPI_ISL_410537.fasta
# Extracting EPI_ISL_410545.fasta
# Extracting EPI_ISL_410546.fasta
# Extracting EPI_ISL_410713.fasta
# Extracting EPI_ISL_410714.fasta
# Extracting EPI_ISL_410715.fasta
# Extracting EPI_ISL_410716.fasta
# Extracting EPI_ISL_410717.fasta
# Extracting EPI_ISL_410718.fasta
# Extracting EPI_ISL_410719.fasta
# Extracting EPI_ISL_410720.fasta
# Extracting EPI_ISL_410984.fasta
# Extracting EPI_ISL_411060.fasta
# Extracting EPI_ISL_411066.fasta
# Extracting EPI_ISL_411218.fasta
# Extracting EPI_ISL_411219.fasta
# Extracting EPI_ISL_411220.fasta
# Extracting EPI_ISL_411902.fasta
# Extracting EPI_ISL_411915.fasta
# Extracting EPI_ISL_411926.fasta
# Extracting EPI_ISL_411927.fasta
# Extracting EPI_ISL_411929.fasta
# Extracting EPI_ISL_411949.fasta
# Extracting EPI_ISL_411950.fasta
# Extracting EPI_ISL_411951.fasta
# Extracting EPI_ISL_411952.fasta
# Extracting EPI_ISL_411953.fasta
# Extracting EPI_ISL_411954.fasta
# Extracting EPI_ISL_411955.fasta
# Extracting EPI_ISL_411956.fasta
# Extracting EPI_ISL_411957.fasta
# Extracting EPI_ISL_411958.fasta
# Extracting EPI_ISL_411959.fasta
# Extracting EPI_ISL_411960.fasta
# Extracting EPI_ISL_411961.fasta
# Extracting EPI_ISL_411962.fasta
# Extracting EPI_ISL_411963.fasta
# Extracting EPI_ISL_411964.fasta
# Extracting EPI_ISL_411965.fasta
# Extracting EPI_ISL_411966.fasta
# Extracting EPI_ISL_411967.fasta
# Extracting EPI_ISL_412026.fasta
# Extracting EPI_ISL_412028.fasta
# Extracting EPI_ISL_412029.fasta
# Extracting EPI_ISL_412030.fasta
# Extracting EPI_ISL_412034.fasta
# Extracting EPI_ISL_412035.fasta
# Extracting EPI_ISL_412036.fasta
# Extracting EPI_ISL_412037.fasta
# Extracting EPI_ISL_412038.fasta
# Extracting EPI_ISL_412039.fasta
# Extracting EPI_ISL_412041.fasta
# Extracting EPI_ISL_412042.fasta
# Extracting EPI_ISL_412043.fasta
# Extracting EPI_ISL_412044.fasta
# Extracting EPI_ISL_412045.fasta
# Extracting EPI_ISL_412046.fasta
# Extracting EPI_ISL_412049.fasta
# Extracting EPI_ISL_412050.fasta
# Extracting EPI_ISL_412051.fasta
# Extracting EPI_ISL_412052.fasta
# Extracting EPI_ISL_412053.fasta
# Extracting EPI_ISL_412054.fasta
# Extracting EPI_ISL_412116.fasta
# Extracting EPI_ISL_412387.fasta
# Extracting EPI_ISL_412418.fasta
# Extracting EPI_ISL_412419.fasta
# Extracting EPI_ISL_412420.fasta
# Extracting EPI_ISL_412421.fasta
# Extracting EPI_ISL_412422.fasta
# Extracting EPI_ISL_412423.fasta
# Extracting EPI_ISL_412424.fasta
# Extracting EPI_ISL_412425.fasta
# Extracting EPI_ISL_412426.fasta
# Extracting EPI_ISL_412459.fasta
# Extracting EPI_ISL_412862.fasta
# Extracting EPI_ISL_412869.fasta
# Extracting EPI_ISL_412870.fasta
# Extracting EPI_ISL_412871.fasta
# Extracting EPI_ISL_412872.fasta
# Extracting EPI_ISL_412873.fasta
# Extracting EPI_ISL_412898.fasta
# Extracting EPI_ISL_412899.fasta
# Extracting EPI_ISL_412900.fasta
# Extracting EPI_ISL_412912.fasta
# Extracting EPI_ISL_412964.fasta
# Extracting EPI_ISL_412965.fasta
# Extracting EPI_ISL_412966.fasta
# Extracting EPI_ISL_412967.fasta
# Extracting EPI_ISL_412968.fasta
# Extracting EPI_ISL_412969.fasta
# Extracting EPI_ISL_412970.fasta
# Extracting EPI_ISL_412971.fasta
# Extracting EPI_ISL_412972.fasta
# Extracting EPI_ISL_412973.fasta
# Extracting EPI_ISL_412974.fasta
# Extracting EPI_ISL_412975.fasta
# Extracting EPI_ISL_412978.fasta
# Extracting EPI_ISL_412979.fasta
# Extracting EPI_ISL_412980.fasta
# Extracting EPI_ISL_412981.fasta
# Extracting EPI_ISL_412982.fasta
# Extracting EPI_ISL_412983.fasta
# Extracting EPI_ISL_413014.fasta
# Extracting EPI_ISL_413015.fasta
# Extracting EPI_ISL_413016.fasta
# Extracting EPI_ISL_413017.fasta
# Extracting EPI_ISL_413018.fasta
# Extracting EPI_ISL_413019.fasta
# Extracting EPI_ISL_413020.fasta
# Extracting EPI_ISL_413021.fasta
# Extracting EPI_ISL_413022.fasta
# Extracting EPI_ISL_413023.fasta
# Extracting EPI_ISL_413024.fasta
# Extracting EPI_ISL_413025.fasta
# Extracting EPI_ISL_413213.fasta
# Extracting EPI_ISL_413214.fasta
# Extracting EPI_ISL_413219.fasta
# Extracting EPI_ISL_413221.fasta
# Loaded Acknowledgement Table with  ['Virus name', 'Location', 'Collection date', 'Originating lab', 'Submitting lab', 'Authors']

# %%
OUTPUT_FILE = 'zoophy.fasta'
MONTH_DICT = {"01":"Jan","02":"Feb","03":"Mar","04":"Apr","05":"May","06":"Jun","07":"Jul","08":"Aug","09":"Sep","10":"Oct","11":"Nov","12":"Dec"}
count_written = 0
with open(OUTPUT_FILE, "w") as ofile:
    for fastafile in listdir(ZIP_DIR):
        try:
            defn_added = False
            for line in open(join(ZIP_DIR, fastafile)):
                if line[0] == ">":
                    name = line.split("|")[0].strip()[1:]
                    accession = line.split("|")[-1].strip()
                    row = xdf.loc[accession]
                    location = ", ".join(reversed([x.strip() for x in row['Location'].split("/")]))
                    if len(row['Collection date'].split("-")) < 3:
                        continue
                    year, month, day = row['Collection date'].split("-")
                    month = MONTH_DICT[month]
                    collection_date = "-".join([day, month, year])
                    defn_line = ">"+"|".join([accession, location, collection_date])
                    print(defn_line.strip(), file=ofile)
                    count_written += 1
                    defn_added = True
                else:
                    if defn_added:
                        print(line.strip(), file=ofile)
            print("", file=ofile)
        except Exception as e:
            print("Exception", e, " while processing fasta file", fastafile, " Hence, skipping.")

print("Formatted ", count_written, "/", len(listdir(ZIP_DIR)), ". Skipped others due to missing data or formatting errors.")
# !grep EPI zoophy.fasta
# Out:
# Formatted  236 / 257 . Skipped others due to missing data or formatting errors.

# %%
files.download(OUTPUT_FILE)
